# %%
import easyocr
reader = easyocr.Reader(['ch_sim','en']) # this needs to run only once to load the model into memory
# Out:
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
result1 = reader.readtext('/Users/alberto/Documents/projects/ks-ocr/data/example1.png')
# Out:
# /Users/alberto/Documents/projects/ks-ocr/venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
list(result1)
# Out:
# [([[np.int32(242), np.int32(22)],
#    [np.int32(562), np.int32(22)],
#    [np.int32(562), np.int32(48)],
#    [np.int32(242), np.int32(48)]],
#   'Reduce your risk of coronavirus infection:',
#   np.float64(0.7269033153716776)),
#  ([[np.int32(313), np.int32(73)],
#    [np.int32(507), np.int32(73)],
#    [np.int32(507), np.int32(89)],
#    [np.int32(313), np.int32(89)]],
#   'Clean hands with soap and Water',
#   np.float64(0.548454896117126)),
#  ([[np.int32(1063), np.int32(73)],
#    [np.int32(1129), np.int32(73)],
#    [np.int32(1129), np.int32(93)],
#    [np.int32(1063), np.int32(93)]],
#   'Mairit 叫 |凹',
#   np.float64(0.016134202417239146)),
#  ([[np.int32(327), np.int32(91)],
#    [np.int32(467), np.int32(91)],
#    [np.int32(467), np.int32(107)],
#    [np.int32(327), np.int32(107)]],
#   'alcoholbased hand (Ub',
#   np.float64(0.39266392411663203)),
#  ([[np.int32(1115), np.int32(114)],
#    [np.int32(1152), np.int32(114)],
#    [np.int32(1152), np.int32(131)],
# ...

# %%
reader.readtext('/Users/alberto/Documents/projects/ks-ocr/data/example2.png', detail = 0)
# Out:
# /Users/alberto/Documents/projects/ks-ocr/venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ["[{[[189,75],[469,75],[469,165],[189,165]],'愚豆珞'",
#  '0.37549895048141481,',
#  '西',
#  '东',
#  '{[[86,80],[134,80],[134,128],[86,128]],',
#  '0.404526591300964361,',
#  '',
#  '愚园路',
#  '309',
#  '{[[517,81], [565,81], [565,123],[517,123]],',
#  "东'",
#  '0.99895989894866941',
#  '{[[78,126],1136,126],1136,156],[78,156]],',
#  "315',0.81258893013000491",
#  'IN',
#  'Yuyuan Rd',
#  'E',
#  '([[514,126],[574,126],[574,156],[514,156]],',
#  "309',0.4971577227115631,",
#  "([226,170],[414,170][414,220].[226,220]], 'Yuyuan Rd.",
#  '0.82619023323059081',
#  '{[[79,173],[125,173],[125,213],[79,213]],',
#  "'W',0.98481112718582151,",
#  '{[[529,173],1569,173],1569,2131,[529,213]],',
#  "E',0.84055936336517331",
#  '[([[71',
# ...

# %%
reader.readtext('/Users/alberto/Documents/projects/ks-ocr/data/example3.png', detail = 0)
# Out:
# /Users/alberto/Documents/projects/ks-ocr/venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ['4酃',
#  'SPEED',
#  'LIWIIT',
#  'BASRURKAR',
#  'NARKET',
#  '50 40"',
#  '',
#  'T',
#  'BASRURKAR MARKET',
#  'SPEED LIMIT']
